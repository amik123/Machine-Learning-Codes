# %%
import pandas as pd
import requests

# %%
url="https://api.themoviedb.org/3/discover/movie"
headers={
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhNzBkMmUzNmU1Njg1OTFiZTJkMmYxZGM3OTQzODVhMSIsInN1YiI6IjY0Yjg5NWZiNGQyM2RkMDE0NDhjNDNlNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.vRG_Vzr8EP6F4B2TFtEKWkDwgazc072HljIYjwfsOe4"
}
params={'page':1}
response=requests.get(url,headers=headers,params=params)
response
# Out:
# <Response [200]>

# %%
df=pd.DataFrame(response.json()['results'])
df=df[['id','title','original_language','overview','release_date','popularity']]
df
# Out:
#          id                                          title original_language  \
# 0    667538               Transformers: Rise of the Beasts                en
# 1    447365                 Guardians of the Galaxy Vol. 3                en
# 2    298618                                      The Flash                en
# 3    385687                                         Fast X                en
# 4    455476                          Knights of the Zodiac                en
# 5    346698                                         Barbie                en
# 6    678512                               Sound of Freedom                en
# 7   1076487                                   Warhorse One                en
# 8    569094            Spider-Man: Across the Spider-Verse                en
# 9    921636                                   The Out-Laws                en
# 10   603692                           John Wick: Chapter 4                en
# ...

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,450):
    url="https://api.themoviedb.org/3/discover/movie"
    headers={
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJhNzBkMmUzNmU1Njg1OTFiZTJkMmYxZGM3OTQzODVhMSIsInN1YiI6IjY0Yjg5NWZiNGQyM2RkMDE0NDhjNDNlNyIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.vRG_Vzr8EP6F4B2TFtEKWkDwgazc072HljIYjwfsOe4"
    }
    params={'page':i}
    response=requests.get(url,headers=headers,params=params)
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','original_language','overview','release_date','popularity']]
    df=df.append(temp_df,ignore_index=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10444\1221426968.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_10444\1221426968.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_10444\1221426968.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# C:\Users\user\AppData\Local\Temp\ipykernel_10444\1221426968.py:10: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(temp_df,ignore_index=True)
# ...

# %%
df.drop_duplicates(inplace=True,ignore_index=True)
df
# Out:
#            id                             title original_language  \
# 0      667538  Transformers: Rise of the Beasts                en
# 1      447365    Guardians of the Galaxy Vol. 3                en
# 2      298618                         The Flash                en
# 3      385687                            Fast X                en
# 4      455476             Knights of the Zodiac                en
# ...       ...                               ...               ...
# 8975  1127235                             Hosto                tl
# 8976     5506                   The Ladykillers                en
# 8977     5236               Kiss Kiss Bang Bang                en
# 8978    12715                        Firewalker                en
# 8979    38843                 Ramona and Beezus                en
#
#                                                overview release_date  \
# 0     When a new threat capable of destroying the en...   2023-06-06
# ...
